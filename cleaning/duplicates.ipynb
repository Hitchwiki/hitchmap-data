# %%
import sqlite3
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

# %%
fn = 'dump.sqlite'
duplicates = pd.read_sql('select * from duplicates', sqlite3.connect(fn))

# %%
duplicates
# Out:
#     id   from_lat   from_lon     to_lat     to_lon  accepted  reviewed ip  \
# 0    1  51.404352   5.538128  51.404547   5.537270         0         0
# 1    2  51.404627   5.542442  51.404547   5.537270         0         0
# 2    3  52.302417  13.019185  52.302168  13.019915         0         0
# 3    4  52.302286  13.019443  52.302168  13.019915         0         0
# 4    5  52.301984  13.020387  52.302168  13.019915         0         0
# 5    6  52.302078  13.020387  52.302168  13.019915         0         0
# 6    7  52.302256  13.020292  52.302168  13.019915         0         0
# 7    8  52.301728  13.017973  52.301472  13.018413         0         0
# 8    9  52.301787  13.017297  52.301472  13.018413         0         0
# 9   10  52.301957  13.017803  52.301472  13.018413         0         0
# 10  11  45.973194   4.732441  45.973277   4.732243         0         0
# 11  12  51.073011  13.667942  51.073075  13.668172         0         0
# ...
