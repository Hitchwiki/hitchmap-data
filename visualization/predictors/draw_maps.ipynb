# %%
from utils_imports import *

with open("models/gp_model.pkl", "rb") as file:
    gpr = pickle.load(file)
# Out:
# /home/till/miniconda3/envs/heatchmap/lib/python3.10/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator GaussianProcessRegressor from version 1.4.1.post1 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/till/miniconda3/envs/heatchmap/lib/python3.10/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator FunctionTransformer from version 1.4.1.post1 when using version 1.4.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
map_from_model(gpr, region="germany", show_uncertainties=False, verbose=True, resolution=10, final=True)
# Out:
#   0%|          | 0/130 [00:00<?, ?it/s]
# Loading country shapes...
# Transforming heatmap...
# max map waiting time: 40.30284179150601
# min map waiting time: 8.22214674770678
# Plotting heatmap...
# max waiting time: 675

# %%
map_from_model(gpr, region="europe", show_uncertainties=False, verbose=True, resolution=10, final=True)
# Out:
#   0%|          | 0/710 [00:00<?, ?it/s]
# Loading country shapes...
# Transforming heatmap...
# max map waiting time: 73.32300422845933
# min map waiting time: 4.725450558707893
# Plotting heatmap...
# max waiting time: 675

# %%
map_from_model(gpr, region="asia", show_uncertainties=True, discrete_uncertainties=True, verbose=True, resolution=10, final=True)
# Out:
# Compute rows of pixels...
#   0%|          | 0/1570 [00:00<?, ?it/s]

# %%
map_from_model(gpr, region="australia", show_uncertainties=True, discrete_uncertainties=True, verbose=True, resolution=10, final=True)
# Out:
#   0%|          | 0/850 [00:00<?, ?it/s]
# Loading country shapes...
# Transforming heatmap...
# max map waiting time: 80.51245077587676
# min map waiting time: 6.526044017018269
# Plotting heatmap...
# max waiting time: 675

# %%
map_from_model(gpr, region="north_america", show_uncertainties=True, discrete_uncertainties=True, verbose=True, resolution=10, final=True)
# Out:
# Compute rows of pixels...
#   0%|          | 0/1200 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 map_from_model(gpr, region="north_america", show_uncertainties=True, discrete_uncertainties=True, verbose=True, resolution=10, final=True)
#
# File ~/projects/hitchhiking/hitchmap-data/visualization/predictors/utils_map.py:140, in map_from_model(model, region, resolution, show_uncertainties, verbose, discrete_uncertainties, return_raster, final)
#     130 def map_from_model(
#     131     model,
#     132     region,
#    (...)
#     138     final=False,
#     139 ):
# --> 140     raster_maker = raster_from_model(
#     141         model,
#     142         region,
#     143         resolution,
#     144         show_uncertainties=show_uncertainties,
#     145         verbose=verbose,
#     146     )
#     147     raster_maker.build_map(
#     148         show_uncertainties=show_uncertainties,
#     149         discrete_uncertainties=discrete_uncertainties,
#     150         final=final,
#     151     )
#     153     if return_raster:
#
# File ~/projects/hitchhiking/hitchmap-data/visualization/predictors/utils_map.py:100, in raster_from_model(model, region, resolution, show_uncertainties, verbose)
#      98 for vertical_line in tqdm(grid.transpose(), disable=not verbose):
#      99     if show_uncertainties:
# --> 100         pred, stdv = model.predict(vertical_line, return_std=True)
#     101         uncertainty_map = np.vstack((uncertainty_map, stdv))
#     102     else:
#
# File ~/projects/hitchhiking/hitchmap-data/visualization/predictors/transformed_target_regressor_with_uncertainty.py:47, in TransformedTargetRegressorWithUncertainty.predict(self, X, return_std, transform_predictions, **predict_params)
#      45 # always return the standard deviation as it is required for the proper inverse_transform
#      46 model: BaseEstimator = self.regressor_
# ---> 47 tran_pred, tran_std = model.predict(X, return_std=True)
#      48 if transform_predictions:
#      49     tran_pred = self.numeric_transformer.inverse_mean_func(tran_pred, tran_std)
#
# File ~/miniconda3/envs/heatchmap/lib/python3.10/site-packages/sklearn/gaussian_process/_gpr.py:439, in GaussianProcessRegressor.predict(self, X, return_std, return_cov)
#     436         return y_mean
#     437 else:  # Predict based on GP posterior
#     438     # Alg 2.1, page 19, line 4 -> f*_bar = K(X_test, X_train) . alpha
# --> 439     K_trans = self.kernel_(X, self.X_train_)
#     440     y_mean = K_trans @ self.alpha_
#     442     # undo normalisation
#
# File ~/miniconda3/envs/heatchmap/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:871, in Sum.__call__(self, X, Y, eval_gradient)
#     869     return K1 + K2, np.dstack((K1_gradient, K2_gradient))
#     870 else:
# --> 871     return self.k1(X, Y) + self.k2(X, Y)
#
# File ~/miniconda3/envs/heatchmap/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:871, in Sum.__call__(self, X, Y, eval_gradient)
#     869     return K1 + K2, np.dstack((K1_gradient, K2_gradient))
#     870 else:
# --> 871     return self.k1(X, Y) + self.k2(X, Y)
#
# File ~/miniconda3/envs/heatchmap/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:871, in Sum.__call__(self, X, Y, eval_gradient)
#     869     return K1 + K2, np.dstack((K1_gradient, K2_gradient))
#     870 else:
# --> 871     return self.k1(X, Y) + self.k2(X, Y)
#
# File ~/miniconda3/envs/heatchmap/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:971, in Product.__call__(self, X, Y, eval_gradient)
#     967     return K1 * K2, np.dstack(
#     968         (K1_gradient * K2[:, :, np.newaxis], K2_gradient * K1[:, :, np.newaxis])
#     969     )
#     970 else:
# --> 971     return self.k1(X, Y) * self.k2(X, Y)
#
# File ~/miniconda3/envs/heatchmap/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:1570, in RBF.__call__(self, X, Y, eval_gradient)
#    1568         raise ValueError("Gradient can only be evaluated when Y is None.")
#    1569     dists = cdist(X / length_scale, Y / length_scale, metric="sqeuclidean")
# -> 1570     K = np.exp(-0.5 * dists)
#    1572 if eval_gradient:
#    1573     if self.hyperparameter_length_scale.fixed:
#    1574         # Hyperparameter l kept fixed
#
# KeyboardInterrupt:

# %%
map_from_model(gpr, region="south_america", show_uncertainties=True, discrete_uncertainties=True, verbose=True, resolution=10, final=True)
# Out:
# Compute rows of pixels...
#   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 map_from_model(gpr, region="south_america", show_uncertainties=True, discrete_uncertainties=True, verbose=True, resolution=10, final=True)
#
# File ~/projects/hitchhiking/hitchmap-data/visualization/predictors/utils_map.py:140, in map_from_model(model, region, resolution, show_uncertainties, verbose, discrete_uncertainties, return_raster, final)
#     130 def map_from_model(
#     131     model,
#     132     region,
#    (...)
#     138     final=False,
#     139 ):
# --> 140     raster_maker = raster_from_model(
#     141         model,
#     142         region,
#     143         resolution,
#     144         show_uncertainties=show_uncertainties,
#     145         verbose=verbose,
#     146     )
#     147     raster_maker.build_map(
#     148         show_uncertainties=show_uncertainties,
#     149         discrete_uncertainties=discrete_uncertainties,
#     150         final=final,
#     151     )
#     153     if return_raster:
#
# File ~/projects/hitchhiking/hitchmap-data/visualization/predictors/utils_map.py:100, in raster_from_model(model, region, resolution, show_uncertainties, verbose)
#      98 for vertical_line in tqdm(grid.transpose(), disable=not verbose):
#      99     if show_uncertainties:
# --> 100         pred, stdv = model.predict(vertical_line, return_std=True)
#     101         uncertainty_map = np.vstack((uncertainty_map, stdv))
#     102     else:
#
# File ~/projects/hitchhiking/hitchmap-data/visualization/predictors/transformed_target_regressor_with_uncertainty.py:47, in TransformedTargetRegressorWithUncertainty.predict(self, X, return_std, transform_predictions, **predict_params)
#      45 # always return the standard deviation as it is required for the proper inverse_transform
#      46 model: BaseEstimator = self.regressor_
# ---> 47 tran_pred, tran_std = model.predict(X, return_std=True)
#      48 if transform_predictions:
#      49     tran_pred = self.numeric_transformer.inverse_mean_func(tran_pred, tran_std)
#
# File ~/miniconda3/envs/heatchmap/lib/python3.10/site-packages/sklearn/gaussian_process/_gpr.py:439, in GaussianProcessRegressor.predict(self, X, return_std, return_cov)
#     436         return y_mean
#     437 else:  # Predict based on GP posterior
#     438     # Alg 2.1, page 19, line 4 -> f*_bar = K(X_test, X_train) . alpha
# --> 439     K_trans = self.kernel_(X, self.X_train_)
#     440     y_mean = K_trans @ self.alpha_
#     442     # undo normalisation
#
# File ~/miniconda3/envs/heatchmap/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:871, in Sum.__call__(self, X, Y, eval_gradient)
#     869     return K1 + K2, np.dstack((K1_gradient, K2_gradient))
#     870 else:
# --> 871     return self.k1(X, Y) + self.k2(X, Y)
#
# File ~/miniconda3/envs/heatchmap/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:871, in Sum.__call__(self, X, Y, eval_gradient)
#     869     return K1 + K2, np.dstack((K1_gradient, K2_gradient))
#     870 else:
# --> 871     return self.k1(X, Y) + self.k2(X, Y)
#
# File ~/miniconda3/envs/heatchmap/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:971, in Product.__call__(self, X, Y, eval_gradient)
#     967     return K1 * K2, np.dstack(
#     968         (K1_gradient * K2[:, :, np.newaxis], K2_gradient * K1[:, :, np.newaxis])
#     969     )
#     970 else:
# --> 971     return self.k1(X, Y) * self.k2(X, Y)
#
# File ~/miniconda3/envs/heatchmap/lib/python3.10/site-packages/sklearn/gaussian_process/kernels.py:1570, in RBF.__call__(self, X, Y, eval_gradient)
#    1568         raise ValueError("Gradient can only be evaluated when Y is None.")
#    1569     dists = cdist(X / length_scale, Y / length_scale, metric="sqeuclidean")
# -> 1570     K = np.exp(-0.5 * dists)
#    1572 if eval_gradient:
#    1573     if self.hyperparameter_length_scale.fixed:
#    1574         # Hyperparameter l kept fixed
#
# KeyboardInterrupt:

# %%
map_from_model(gpr, region="africa", show_uncertainties=True, discrete_uncertainties=True, verbose=True, resolution=10, final=True)
