# %%
import pandas as pd
import networkx as nx
import numpy as np
from tqdm import tqdm
import folium

# %%
def haversine_np(lon1, lat1, lon2, lat2, factor=1.25):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)

    All args must be of equal length.

    """
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = np.sin(dlat / 2.0) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2.0) ** 2

    c = 2 * np.arcsin(np.sqrt(a))
    km = 6367 * c
    # 1.25 because the road distance is, on average, 25% larger than a straight flight
    return factor * km

# %%
points = pd.read_csv("points.csv")
df = points[~points["dest_lon"].isna()]
df.head()
# Out:
# /var/folders/x9/x6m_v2y54yx2wmzg6z8dczgr0000gn/T/ipykernel_10630/433528718.py:1: DtypeWarning: Columns (14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   points = pd.read_csv("points.csv")
#               id        lat         lon  rating country   wait nickname  \
# 18195      18207  49.635165    5.970091     4.0      LU    NaN      NaN
# 49943   78546373  50.576778 -111.871741     1.0      CA  120.0     DSLR
# 49944  183954465  46.286302  -81.775566     4.0      CA   10.0     DSLR
# 49945  397517487  50.998767 -118.229634     3.0      CA  100.0     DSLR
# 49946  419660441  51.263986 -115.935150     5.0      CA    8.0     DSLR
#
#                                                  comment  \
# 18195  Got a ride after 10 minutes withhout even both...
# 49943  Freeway with high speed traffic, no good spots...
# 49944                                                NaN
# 49945  Traffic is low and lots of local traffic, but ...
# 49946  The transcanada was closed between lake Louise...
#
#                          datetime  reviewed  banned  ip   dest_lat  \
# 18195  2017-09-03 20:40:31.000000         1       0 NaN  47.686400
# 49943  2022-11-06 07:37:11.530351         0       0 NaN  50.576778
# 49944  2022-11-06 06:49:38.987729         0       0 NaN  46.286302
# 49945  2022-11-06 07:49:16.533041         0       0 NaN  50.998767
# 49946  2022-11-06 07:46:31.586044         0       0 NaN  51.263986
#
#          dest_lon signal ride_datetime  user_id  from_hitchwiki
# 18195    6.494300    NaN           NaN      NaN             NaN
# 49943 -114.059811    NaN           NaN      NaN             0.0
# 49944  -84.341174    NaN           NaN      NaN             0.0
# 49945 -117.816645    NaN           NaN      NaN             0.0
# 49946 -118.214006    NaN           NaN      NaN             0.0

# %%
min_lon = 4.2
max_lon = 5
min_lat = 51
max_lat = 53
df = df[df["lon"] > min_lon]
df = df[df["lon"] < max_lon]
df = df[df["lat"] < max_lat]
df = df[df["lat"] > min_lat]
df = df[df["dest_lon"] > min_lon]
df = df[df["dest_lon"] < max_lon]
df = df[df["dest_lat"] < max_lat]
df = df[df["dest_lat"] > min_lat]

# %%
g = nx.DiGraph()

# %%
for _, row in df.iterrows():
    dist = haversine_np(row.lon, row.lat, row.dest_lon, row.dest_lat)
    if dist > 100:
        g.add_edge(
            (row.lon, row.lat),
            (row.dest_lon, row.dest_lat),
            weight=dist,
        )

# %%
g.edges(data=True)
# Out:
# OutEdgeDataView([((4.641155004501344, 51.358058223372055), (4.916381835937501, 52.35798989363364), {'weight': np.float64(140.88925387475976)}), ((4.464193582534791, 51.26278594613045), (4.880676269531251, 52.36805320057393), {'weight': np.float64(157.638463436889)}), ((4.4445168972, 51.2078714778), (4.9219608306884775, 52.376175552387224), {'weight': np.float64(167.38785094683374)}), ((4.41653609275818, 51.2636637361032), (4.492979049682618, 52.14665732565445), {'weight': np.float64(122.82982252297877)})])

# %%
len(g.nodes)
# Out:
# 8

# %%
m = folium.Map([50.7, 4.2], zoom_start=7)

# %%
points = list(g.nodes)
for p in points:
    folium.Marker(location=(p[1], p[0])).add_to(m)

for e in g.edges:
    folium.PolyLine(
        [[e[0][1], e[0][0]], [e[1][1], e[1][0]]],
        color="#FF0000",
        weight=5,
    ).add_to(m)

    folium.RegularPolygonMarker(location=[e[1][1], e[1][0]], fill_color='blue', number_of_sides=3, radius=10).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48d15bbd852fa46b56203ecbf6f8f584 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48d15bbd852fa46b56203ecbf6f8f584&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48d15bbd852fa46b56203ecbf6f8f584 = L.map(
#                 &quot;map_48d15bbd852fa46b56203ecbf6f8f584&quot;,
#                 {
#                     center: [50.7, 4.2],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79675254f7e8ab807b3c4464e783bdc1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_79675254f7e8ab807b3c4464e783bdc1.addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_1e722cf6fec955ccbfb5b5ce8545bbb5 = L.marker(
#                 [51.358058223372055, 4.641155004501344],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_4c663df6d4090c625de15cdeca69d82a = L.marker(
#                 [52.35798989363364, 4.916381835937501],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_1bfaa3c391c58b30e092467ae491911d = L.marker(
#                 [51.26278594613045, 4.464193582534791],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_cb3de30f3ea2b9eb920880d79d1a825e = L.marker(
#                 [52.36805320057393, 4.880676269531251],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_47485581ce294979b6fabc9660a44e33 = L.marker(
#                 [51.2078714778, 4.4445168972],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_d97523fba15d2f8f4293664323e3095a = L.marker(
#                 [52.376175552387224, 4.9219608306884775],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_d39f589a22c87668e5d36655ad4bd514 = L.marker(
#                 [51.2636637361032, 4.41653609275818],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_feb3495546c7b58e4868da94023d79da = L.marker(
#                 [52.14665732565445, 4.492979049682618],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var poly_line_9dc965cf8a1f06b1b3b69fa15004ce5c = L.polyline(
#                 [[51.358058223372055, 4.641155004501344], [52.35798989363364, 4.916381835937501]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var regular_polygon_marker_74a718b6f5d47114629d9b2800ef0f81 = new L.RegularPolygonMarker(
#                 [52.35798989363364, 4.916381835937501],
#                 {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;blue&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 10,
#   &quot;numberOfSides&quot;: 3,
#   &quot;rotation&quot;: 0,
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var poly_line_0158fd49b162556ca44149fd8e2ef38a = L.polyline(
#                 [[51.26278594613045, 4.464193582534791], [52.36805320057393, 4.880676269531251]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_48d15bb

# %%
# make it fully connected with walking paths
for n1 in g.nodes:
    for n2 in g.nodes:
        if n1 != n2:
            dist = haversine_np(n1[0], n1[1], n2[0], n2[1])
            g.add_edge(
                n1,
                n2,
                weight=dist * 20,
            )

# %%
points = list(g.nodes)
for p in points:
    folium.Marker(location=(p[1], p[0])).add_to(m)

for e in g.edges:
    folium.PolyLine(
        [[e[0][1], e[0][0]], [e[1][1], e[1][0]]],
        color="#FF0000",
        weight=5,
    ).add_to(m)

    folium.RegularPolygonMarker(location=[e[1][1], e[1][0]], fill_color='blue', number_of_sides=3, radius=10).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48d15bbd852fa46b56203ecbf6f8f584 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48d15bbd852fa46b56203ecbf6f8f584&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48d15bbd852fa46b56203ecbf6f8f584 = L.map(
#                 &quot;map_48d15bbd852fa46b56203ecbf6f8f584&quot;,
#                 {
#                     center: [50.7, 4.2],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79675254f7e8ab807b3c4464e783bdc1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_79675254f7e8ab807b3c4464e783bdc1.addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_1e722cf6fec955ccbfb5b5ce8545bbb5 = L.marker(
#                 [51.358058223372055, 4.641155004501344],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_4c663df6d4090c625de15cdeca69d82a = L.marker(
#                 [52.35798989363364, 4.916381835937501],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_1bfaa3c391c58b30e092467ae491911d = L.marker(
#                 [51.26278594613045, 4.464193582534791],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_cb3de30f3ea2b9eb920880d79d1a825e = L.marker(
#                 [52.36805320057393, 4.880676269531251],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_47485581ce294979b6fabc9660a44e33 = L.marker(
#                 [51.2078714778, 4.4445168972],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_d97523fba15d2f8f4293664323e3095a = L.marker(
#                 [52.376175552387224, 4.9219608306884775],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_d39f589a22c87668e5d36655ad4bd514 = L.marker(
#                 [51.2636637361032, 4.41653609275818],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_feb3495546c7b58e4868da94023d79da = L.marker(
#                 [52.14665732565445, 4.492979049682618],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var poly_line_9dc965cf8a1f06b1b3b69fa15004ce5c = L.polyline(
#                 [[51.358058223372055, 4.641155004501344], [52.35798989363364, 4.916381835937501]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var regular_polygon_marker_74a718b6f5d47114629d9b2800ef0f81 = new L.RegularPolygonMarker(
#                 [52.35798989363364, 4.916381835937501],
#                 {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;blue&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 10,
#   &quot;numberOfSides&quot;: 3,
#   &quot;rotation&quot;: 0,
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var poly_line_0158fd49b162556ca44149fd8e2ef38a = L.polyline(
#                 [[51.26278594613045, 4.464193582534791], [52.36805320057393, 4.880676269531251]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_48d15bb

# %%
def find_route(G, departure, arrival):
    a = len(G.edges)

    prev_nodes = list(G.nodes)
    for n in prev_nodes:
        dist = haversine_np(arrival[0], arrival[1], n[0], n[1])
        G.add_edge(
            n,
            arrival,
            weight=dist * 20,
        )

    prev_nodes = list(G.nodes)
    for n in prev_nodes:
        dist = haversine_np(departure[0], departure[1], n[0], n[1])
        G.add_edge(
            departure,
            n,
            weight=dist * 20,
        )

  

    print(len(G.edges) - a)

    return G, nx.dijkstra_path(G, departure, arrival), nx.dijkstra_path_length(G, departure, arrival)

# %%
amsterdam = (4.7, 52.6) # Amsterdam
antwerp = (4.4, 51.1) # Barcelona
g, route, length = find_route(g, antwerp, amsterdam)
route, length
# Out:
# 17
# ([(4.4, 51.1), (4.7, 52.6)], np.float64(4198.863125878438))

# %%
points = list(g.nodes)
for p in points:
    folium.Marker(location=(p[1], p[0])).add_to(m)

for e in g.edges:
    folium.PolyLine(
        [[e[0][1], e[0][0]], [e[1][1], e[1][0]]],
        color="#FF0000",
        weight=5,
    ).add_to(m)

    folium.RegularPolygonMarker(location=[e[1][1], e[1][0]], fill_color='blue', number_of_sides=3, radius=10).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48d15bbd852fa46b56203ecbf6f8f584 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48d15bbd852fa46b56203ecbf6f8f584&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48d15bbd852fa46b56203ecbf6f8f584 = L.map(
#                 &quot;map_48d15bbd852fa46b56203ecbf6f8f584&quot;,
#                 {
#                     center: [50.7, 4.2],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79675254f7e8ab807b3c4464e783bdc1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_79675254f7e8ab807b3c4464e783bdc1.addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_1e722cf6fec955ccbfb5b5ce8545bbb5 = L.marker(
#                 [51.358058223372055, 4.641155004501344],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_4c663df6d4090c625de15cdeca69d82a = L.marker(
#                 [52.35798989363364, 4.916381835937501],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_1bfaa3c391c58b30e092467ae491911d = L.marker(
#                 [51.26278594613045, 4.464193582534791],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_cb3de30f3ea2b9eb920880d79d1a825e = L.marker(
#                 [52.36805320057393, 4.880676269531251],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_47485581ce294979b6fabc9660a44e33 = L.marker(
#                 [51.2078714778, 4.4445168972],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_d97523fba15d2f8f4293664323e3095a = L.marker(
#                 [52.376175552387224, 4.9219608306884775],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_d39f589a22c87668e5d36655ad4bd514 = L.marker(
#                 [51.2636637361032, 4.41653609275818],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var marker_feb3495546c7b58e4868da94023d79da = L.marker(
#                 [52.14665732565445, 4.492979049682618],
#                 {
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var poly_line_9dc965cf8a1f06b1b3b69fa15004ce5c = L.polyline(
#                 [[51.358058223372055, 4.641155004501344], [52.35798989363364, 4.916381835937501]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var regular_polygon_marker_74a718b6f5d47114629d9b2800ef0f81 = new L.RegularPolygonMarker(
#                 [52.35798989363364, 4.916381835937501],
#                 {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;blue&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 10,
#   &quot;numberOfSides&quot;: 3,
#   &quot;rotation&quot;: 0,
# }
#             ).addTo(map_48d15bbd852fa46b56203ecbf6f8f584);
#
#
#             var poly_line_0158fd49b162556ca44149fd8e2ef38a = L.polyline(
#                 [[51.26278594613045, 4.464193582534791], [52.36805320057393, 4.880676269531251]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_48d15bb
