# %%
import pandas as pd
import re
import requests
import random

from tqdm import tqdm
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# from tqdm.auto import tqdm  # for notebooks

# Create new `pandas` methods which use `tqdm` progress
# (can use tqdm_gui, optional kwargs, etc.)
tqdm.pandas()

pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", None)

# %%
# collect all routes from routes.dat and store their related rides
rides = []

# %%
# lines with a route start with "{H"
# their format is not consistent, but usually looks like this:
# {H}
with open("routes.dat") as f:
    for line in f:
        if line.startswith("{H"):
            this = []
            # clean
            line = re.sub(" +", " ", line)
            line = re.sub(" : ", " ", line)

            parts = line.split(" ")

            # get trip and ride numbers that should be integers; one trip can consist of multiple rides
            try:
                trip, ride = parts[1].split(".")
            except:
                continue
            trip = trip.lstrip("0")
            ride = ride.lstrip("0").rstrip(":")
            try:
                _ = int(trip)
                _ = int(ride)
            except:
                continue
            this.append(trip)
            this.append(ride)

            # short links do not contain coordinates of the route
            short_link = parts[2].rstrip("\n")
            this.append(short_link)

            # a long link is not present for all entries
            if len(parts) > 3 and "google" in parts[-1]:
                long_link = parts[-1]
                this.append(long_link)
            else:
                this.append(None)

            rides.append(this)

# %%
rides = pd.DataFrame(rides, columns=["trip", "ride", "short_link", "long_link"])

# %%
# tear rides apart

# rides where long link to google maps route is missing
short = rides[rides.long_link.isna()]
long = rides[~rides.long_link.isna()]

# %%
# drop short links that do not work anymore (a google thing)
short = short[short.short_link.apply(lambda x: "/" in x and len(x.split("/")[-1]) > 5)]

# %%
def get_long(url):
    """Get the long url from the short url"""
    response = requests.get(url)
    if response.history:
        resp = response.history[-1]
        return resp.url


short["long_link"] = short.short_link.progress_apply(get_long)
# Out:
# 100%|██████████| 340/340 [04:58<00:00,  1.14it/s]

# %%
long[long[['trip', 'ride']].duplicated(keep=False)]
# Out:
#      trip ride                                 short_link  \
# 0      11   66           https://goo.gl/maps/rrDA3DvnWGC2
# 1      11   66           https://goo.gl/maps/jachNyRVGQD2
# 2      11   66           https://goo.gl/maps/cZMotNfQx182
# 3      11   66           https://goo.gl/maps/yX5QH6G6ibQ2
# 4      11   66           https://goo.gl/maps/PmH25y82cr42
# 5      11   66           https://goo.gl/maps/B5Z6Rw5gaZT2
# 14     51    7  https://maps.app.goo.gl/mFMME5RpcH6fmBN58
# 15     51    8  https://maps.app.goo.gl/eaMTBr1cidWS2aPn6
# 26     51    7                   http://goo.gl/maps/tGZQj
# 27     51    8                   http://goo.gl/maps/FXl88
# 905   186    6      https://goo.gl/maps/2L47meHyrzLTttAk9
# 906   186    7      https://goo.gl/maps/bDUh1k4k3uxxrJNo8
# 910   186    6      https://goo.gl/maps/fukLvN4foNWKqQ339
# 911   186    7      https://goo.gl/maps/TEEMq9cCdq63C1ir6
# 1142  200    6           https://goo.gl/maps/GQpmTUQiPXH2
# 1143  200    6           https://goo.gl/maps/Y1ndR9hZ8qT2
# 1271  210    4      https://goo.gl/maps/y3zD4wvfKPtYCg3z7
# 1272  210    4      https://goo.gl/maps/gCHJv8e2ayhx62F89
# 1329  214    4      https://goo.gl/maps/2ZAo749yYAMVMf399
# 1330  214    4      https://goo.gl/maps/Yf91CjgVuKoT9tWLA
# 1629  239    1      https://goo.gl/maps/e63UjQANjGQxqJo99
# 2679                                                                                                                                                                                                                                                                                                        https://www.google.com/maps/dir/54.6967386,24.0746967/54.7084476,24.0059214/54.7410016,23.9298624/@54.7180787,23.9198947,12z/data=!4m2!4m1!3e0\n
# 2680                                                                                                                                                                                                                                                                                                        https://www.google.com/maps/dir/54.7410016,23.9298624/55.0304538,23.8284543/55.1964844,23.7150749/@54.9898605,23.5964207,10z/data=!4m2!4m1!3e0\n
# 2681                                                                                                                                                                                                                                                                                                     https://www.google.com/maps/dir/55.1964844,23.7150749/55.1283575,23.5025449/55.0986829,23.1284606/@55.1091338,23.2793884,10.79z/data=!4m2!4m1!3e0\n
# 2682                                                                                                                                                                                                                                 https://www.google.com/maps/dir/55.0986829,23.1284606/Kestucio+g.+24,+74165+Jurbarkas/@55.0810825,22.844657,11.46z/data=!4m9!4m8!1m0!1m5!1m1!1s0x46e6a17f430a3b41:0x6294a8ca69968d0d!2m2!1d22.776341!2d55.0850147!3e0\n
# 2683                                                                                                                                                                                    https://www.google.com/maps/dir/Kestucio+g.+24,+74165+Jurbarkas/''/55.0756482,22.7599836/@55.0812203,22.7565474,15z/data=!3m1!4b1!4m13!4m12!1m5!1m1!1s0x46e6a17f430a3b41:0x6294a8ca69968d0d!2m2!1d22.776341!2d55.0850147!1m3!2m2!1d22.7748433!2d55.0866923!1m0!3e0\n
# 2684                                                                                                                                                                                                                                                                                                      https://www.google.com/maps/dir/55.0756482,22.7599836/55.201147,22.9692071/55.3892991,23.1153281/@55.2330558,22.6983138,10.58z/data=!4m2!4m1!3e0\n
# 2685                                                                                                                                                                                                                                                                                                     https://www.google.com/maps/dir/55.3892991,23.1153281/55.3773212,22.9582841/55.4614361,22.6956765/@55.4291885,22.7955046,11.29z/data=!4m2!4m1!3e0\n
# 2686                                                                                                                                                                                                                                                                                                     https://www.google.com/maps/dir/55.4614361,22.6956765/55.6292884,21.9769638/55.7213527,21.9504071/@55.5766389,22.1200639,10.46z/data=!4m2!4m1!3e0\n
# 2687                                                                                                                                                                                                                                                                                                      https://www.google.com/maps/dir/55.7213527,21.9504071/55.6932335,21.7074435/55.7043311,21.2217592/@55.706869,21.3755703,10.29z/data=!4m2!4m1!3e0\n

# %%
# put rides together again
rides = pd.concat([short, long])

# %%
rides.head()
# Out:
#     trip ride                             short_link  \
# 56   111    5  https://goo.gl/maps/nPDpQ2hQAEeckcdu7
# 57   111    6  https://goo.gl/maps/AMBNuHagai7op1kWA
# 405  156    1       https://goo.gl/maps/KHVVYLk9Zh12
# 514  162    6       https://goo.gl/maps/T1hzytoX3N22
# 516  162    8       https://goo.gl/maps/2DN7KJ5vmn32
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                       long_link
# 56                                                                                                                                                                                                                                                                                                       https://www.google.com/maps/@48.5947235,2.4420642,3a,75y,113.75h,75.55t/data=!3m6!1e1!3m4!1s-ssX8hMOyuRI_zQqrIbeLA!2e0!7i16384!8i8192?hl=en&shorturl=1
# 57                                                                                                                                                                                                                                                                                                       https://www.google.com/maps/@45.7412172,4.4635113,3a,75y,342.25h,84.72t/data=!3m6!1e1!3m4!1skYdB-2HcGy8P3ZwyD1LsJA!2e0!7i13312!8i6656?hl=en&shorturl=1
# 405                                                                                                                                                                                                                                                                                                       https://www.google.com/maps/dir/54.763469,25.080691/54.935537,23.870589/@54.7604884,24.2133912,10z/data=!4m6!4m5!1m1!4e1!1m1!4e1!3e0?hl=en&shorturl=1
# 514  https://www.google.com/maps/dir/54.3589914,23.1822141/52.3015858,13.0213019/@53.4176585,15.8157329,7z/data=!4m24!4m23!1m20!3m4!1m2!1d20.257172!2d53.7483332!3s0x471d7fceac1ea77b:0x63f879a034e4862d!3m4!1m2!1d19.5403897!2d54.1015715!3s0x46e2b25b2148c057:0x6bc3a212f78c2d55!3m4!1m2!1d16.6583117!2d53.3723023!3s0x470162482dc1302d:0x8fba958abc940158!3m4!1m2!1d14.6228172!2d53.3782926!3s0x4700a7f3c1a3815b:0xed6df1353198568d!1m0!3e0?hl=en&shorturl=1
# 516                                                                                                                                                                                                                https://www.google.com/maps/dir/52.2520523,12.3086909/Rasthof+Lehrter+See+Nord,+Lehrte,+Germany/@52.149435,10.5941378,9z/data=!4m9!4m8!1m0!1m5!1m1!1s0x47b0058ca1c6d2c3:0x34883c21066e75c6!2m2!1d9.9954637!2d52.3886797!3e0?hl=en&shorturl=1

# %%
# drop instances with links that are no routes (street view)
rides = rides[rides.long_link.str.contains("/dir/")]
# Out:
#    trip ride                             short_link  \
# 56  111    5  https://goo.gl/maps/nPDpQ2hQAEeckcdu7
# 57  111    6  https://goo.gl/maps/AMBNuHagai7op1kWA
# 60  111   12  https://goo.gl/maps/QWXVtQzGGF4kzRMT9
#
#                                                                                                                                                  long_link
# 56  https://www.google.com/maps/@48.5947235,2.4420642,3a,75y,113.75h,75.55t/data=!3m6!1e1!3m4!1s-ssX8hMOyuRI_zQqrIbeLA!2e0!7i16384!8i8192?hl=en&shorturl=1
# 57  https://www.google.com/maps/@45.7412172,4.4635113,3a,75y,342.25h,84.72t/data=!3m6!1e1!3m4!1skYdB-2HcGy8P3ZwyD1LsJA!2e0!7i13312!8i6656?hl=en&shorturl=1
# 60                     https://www.google.com/maps/@45.360087,1.5716114,3a,75y,230.63h,90t/data=!3m6!1e1!3m4!1s5sq37hxjPuZfQsbuNt7enw!2e0!7i13312!8i6656\n

# %%
def get_start(url):
    """Extract the start coordinates from the url"""
    start = re.findall(r"dir/(.*?)/", url)[0]
    if not start[0].isnumeric():
        start = list(re.findall(r"!1d(.*?)!2d(.*?)!", url)[0])
    else:
        start = start.split(",")
    return start


def get_end(url):
    """Extract the end coordinates from the url"""
    end = re.findall(r"/.*/(.*)/@", url)[0]
    if not end[0].isnumeric():
        end = list(re.findall(r"!1d(.*?)!2d(.*?)!", url)[-1])
    else:
        end = end.split(",")

    return end

# %%
rides["start"] = rides.long_link.progress_apply(get_start)
rides["end"] = rides.long_link.progress_apply(get_end)
# Out:
# 100%|██████████| 2835/2835 [00:00<00:00, 243819.88it/s]
# 100%|██████████| 2835/2835 [00:00<00:00, 57500.95it/s]

# %%
# instances with same trip + ride mark stops of the vehicle or border crossings
# the way this is used is inconsistent, sometimes a second occurende of the same trip + ride actually matches another ride
# we will take the start point of of first route and the coordinates of the destination (from rides.csv) as the route

ides["stop"] = rides.groupby(["trip", "ride"]).cumcount()

# %%
df = pd.read_csv(
    "rides.csv",
    names=[
        "trip",
        "ride",
        "departure_date",
        "departure_time",
        "departure_odometer_km",
        "arrival_date",
        "arrival_time",
        "arrival_odometer_km",
        "distance_km",
        "duration_h",
        "velocity_kmh",
        "waiting_time",
        "driver_country",
        "driver_type",
        "departure_country",
        "arrival_country",
        "departure_type_method",
        "departure_type_location",
        "departure_location",
        "arrival_location",
        # irrelevant columns
        "drop_1",
        "drop_2",
        "drop_3",
    ],
    index_col=False,
)
# Out:
# /tmp/ipykernel_44884/3602134457.py:1: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv(

# %%
df = df.drop(columns=["drop_1", "drop_2", "drop_3"])

# %%
def get_time(x):
    """Retrieve the time in minutes from a string"""
    try:
        t = datetime.strptime(x, "%H:%M")
        d = timedelta(hours=t.hour, minutes=t.minute)
        return int(d.total_seconds() // 60)
    except Exception as e:
        return None

df["waiting_time"] = df["waiting_time"].apply(get_time)

# %%
dsjf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 dsjf
#
# NameError: name 'dsjf' is not defined

# %%
full = pd.merge(all, df, on=["trip", "ride", "stop"], how="left")

# %%
full.dropna(subset=["departure_date"], inplace=True) # drop where no match could be found in rides table

# %%
full = full[full.departure_type_method != "q"] # prearranged rides

# %%
full["departure_type_method"] = full.departure_type_method.map({"a":"ask", "t":"thumb", "i":"invited"})

# %%
full.reset_index(drop=True, inplace=True)

# %%
# export to hitchmap format

hm = pd.DataFrame()
hm["id"] = [random.randint(9219501639295889231, 1e20) for _ in range(len(full))]
hm["lat"] = full.start.apply(lambda x: float(x.split(",")[0].lstrip("['").rstrip("'")))
hm["lon"] = full.start.apply(lambda x: float(x.split(",")[1].rstrip("']").lstrip(" '")))
hm["rating"] = None
hm["country"] = full.departure_country
hm["wait"] = full.waiting_time
hm["name"] = "Prino"  # https://hitchwiki.org/en/User:Prino
hm["comment"] = None
hm["datetime"] = full.departure_date + " " + full.departure_time + ":00.000000" # using datatime_ride so that one can see age of the ride on the frontend
hm["reviewed"] = 1
hm["banned"] = 0
hm["ip"] = None
hm["dest_lat"] = full.end.apply(
    lambda x: float(x.split(",")[0].lstrip("['").rstrip("'"))
)
hm["dest_lon"] = full.end.apply(
    lambda x: float(x.split(",")[1].rstrip("']").lstrip(" '"))
)
hm["signal"] = full.departure_type_method
hm["datetime_ride"] = full.departure_date + " " + full.departure_time + ":00.000000"
hm["gender"] = "male"
hm["age"] = full.departure_date.apply(
    lambda x: relativedelta(
        datetime.strptime(x, "%Y-%m-%d").date(), datetime(1960, 1, 1)
    ).years
)  # roughly
# new features
hm["driver_country"] = full.driver_country
hm["driver_gender"] = full.driver_type.map(
    {
        "-": "male",
        "V": "female",
        "E": "mixed",
        "F": "mixed",
        "V*": "female",
        "-*": "male",
        "Elec": "male",
        "V-El": "female",
        "Por":"male",
        "VPor":"female",
        "T":"male",
    },
    na_action=None,
)
hm["vehicle"] = full.driver_type.map(
    {
        "T": "truck",
        "B": "van",
        "MB": "bus",
        "C": "camper",
        "Bus": "bus",
        "M": "motorbike",
    },
    na_action=None,
)
hm["vehicle"] = hm.vehicle.fillna("car")

# %%
hm.comment.astype(str).replace("nan", None, inplace=True)

# %%
hm.to_csv("prino_to_hitchmap.csv", index=False)
